# %% [markdown]
# # Topic Modeling the Native Voices Corpus

# %% [markdown]
# ## Methods and Preprocessing
#
# To create each model, I used the Latent Dirichlet Allocation algorithm instantiated in MALLET, a command-line package for topic modeling.
#
# <b>Parameters:</b> In addition to specifying the number of topics, I also used the optimize-interval option, set to 20 to ensure more accuracy in the weighting of topics.
#
# <b>Output:</b> I output the following files for present and future analysis:
# <ul>
#     <li>topic-states.gz for use in with pyLDAvis</li>
#     <li>topic-keys.txt, which I then converted to a csv file by replacing tabs with commas, saving it as this alternative file format with UTF-8 encoding, and adding a header row</li>
#     <li>doc-topics.txt, which I converted to a csv file by replacing tabs with commas, and saving it as a csv with UTF-8 encoding. I then removed the first two columns with document numbers and filepaths, converted the scientific notation to numerals with six digits after the decimal place, and added a header after manually labeling each of the topics based on my analysis of the keys file.</li>
#     <li>word-topic-counts-file as a txt file, which I've saved for potential later analysis and visualization using word clouds.</li>
# </ul>

# %% [markdown]
# ## Experimental Visualizations

# %%
# Open the topic-keys.txt that you created with MALLET. Replace the tab characters with commas. 
# Then save that file as a .csv.

import pandas as pd

nv15_topics = pd.Cov = pd.read_csv("/Users/ritc/Desktop/DRC/NV/malletfiles/15/csv/nv15-keys.csv", sep=',', names=["topic_number", "topic_weight", "top_words"])

# nv15_topics

nv15_topics.style.set_properties(subset=['top_words'], **{'width': '600px'})
# Out:
# <style  type="text/css" >
#     #T_85f8a50e_9236_11ea_a323_f018986d65f5row0_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row1_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row2_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row3_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row4_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row5_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row6_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row7_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row8_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row9_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row10_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row11_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row12_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row13_col2 {
#             width:  600px;
#         }    #T_85f8a50e_9236_11ea_a323_f018986d65f5row14_col2 {
#             width:  600px;
#         }</style><table id="T_85f8a50e_9236_11ea_a323_f018986d65f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >topic_number</th>        <th class="col_heading level0 col1" >topic_weight</th>        <th class="col_heading level0 col2" >top_words</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row0_col1" class="data row0 col1" >0.061000</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row0_col2" class="data row0 col2" >fort general miles men captain harmar day arrived river ohio hundred lieutenant company major left troops army officers parsons pitt </td>
#             </tr>
#             <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row1_col1" class="data row1 col1" >0.048240</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row1_col2" class="data row1 col2" >georgia treaty general commissioners states agent state united chiefs president creek nation government colonel letter council governor mcintosh hawkins department </td>
#             </tr>
#             <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row2_col1" class="data row2 col1" >0.060710</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row2_col2" class="data row2 col2" >language indian society man christian great words word called languages manner means lenape delaware good nations english call forms place </td>
#             </tr>
#             <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row3_col1" class="data row3 col1" >0.066140</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row3_col2" class="data row3 col2" >river miles country water small red side mouth hundred west creek land high called lake black missouri found great large </td>
#             </tr>
#             <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row4_col1" class="data row4 col1" >0.043180</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row4_col2" class="data row4 col2" >indians indian department rations agent cents florida pounds governor hundred war john secretary march lbs services june letter yards account </td>
#             </tr>
#             <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row5_col1" class="data row5 col1" >0.085330</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row5_col2" class="data row5 col2" >general states united nations fort troops president ohio sir letter major war secretary hundred captain militia pay governor frontiers peace </td>
#             </tr>
#             <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row6_col1" class="data row6 col1" >0.057850</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row6_col2" class="data row6 col2" >amount indian trade goods factory march agent agents year received office april georgetown furs traders superintendent statement account merchandise peltries </td>
#             </tr>
#             <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row7_col1" class="data row7 col1" >0.155600</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row7_col2" class="data row7 col2" >treaty states united nation lands land commissioners line river president state part thousand hundred dollars made creek chiefs boundary tract </td>
#             </tr>
#             <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row8_col1" class="data row8 col1" >0.125430</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row8_col2" class="data row8 col2" >brethren indians held sunday saviour service preached david detroit back indian church people saturday early monday time wednesday tuesday thursday </td>
#             </tr>
#             <tr>
#                         <th id="T_85f8a50e_9236_11ea_a323_f018986d65f5level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row9_col0" class="data row9 col0" >9</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row9_col1" class="data row9 col1" >0.145300</td>
#                         <td id="T_85f8a50e_9236_11ea_a323_f018986d65f5row9_col2" class="data row9 col2" >men march ene

# %%
# Create a list of topic labels.
labels = ['0 militaryohio','1 treatiesgeorgia','2 language','3 naturalfeatures','4 governmentregulations','5 military','6 trade','7 treaties','8 religion','9 military2','10 governmentregulations2','11 treaties2','12 native-usrelations','13 georgia','14 treatycouncils']
# Add the labels list as a new column to the dataframe
nv15_topics['labels'] = labels

# Adjust the style of the dataframe so that the column of top_words is wide enough to see all of them.
nv15_topics.style.set_properties(subset=['top_words'], **{'width': '500px'})
# Out:
# <style  type="text/css" >
#     #T_85fd9ed8_9236_11ea_a323_f018986d65f5row0_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row1_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row2_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row3_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row4_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row5_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row6_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row7_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row8_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row9_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row10_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row11_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row12_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row13_col2 {
#             width:  500px;
#         }    #T_85fd9ed8_9236_11ea_a323_f018986d65f5row14_col2 {
#             width:  500px;
#         }</style><table id="T_85fd9ed8_9236_11ea_a323_f018986d65f5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >topic_number</th>        <th class="col_heading level0 col1" >topic_weight</th>        <th class="col_heading level0 col2" >top_words</th>        <th class="col_heading level0 col3" >labels</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_85fd9ed8_9236_11ea_a323_f018986d65f5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row0_col1" class="data row0 col1" >0.061000</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row0_col2" class="data row0 col2" >fort general miles men captain harmar day arrived river ohio hundred lieutenant company major left troops army officers parsons pitt </td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row0_col3" class="data row0 col3" >0 militaryohio</td>
#             </tr>
#             <tr>
#                         <th id="T_85fd9ed8_9236_11ea_a323_f018986d65f5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row1_col1" class="data row1 col1" >0.048240</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row1_col2" class="data row1 col2" >georgia treaty general commissioners states agent state united chiefs president creek nation government colonel letter council governor mcintosh hawkins department </td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row1_col3" class="data row1 col3" >1 treatiesgeorgia</td>
#             </tr>
#             <tr>
#                         <th id="T_85fd9ed8_9236_11ea_a323_f018986d65f5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row2_col1" class="data row2 col1" >0.060710</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row2_col2" class="data row2 col2" >language indian society man christian great words word called languages manner means lenape delaware good nations english call forms place </td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row2_col3" class="data row2 col3" >2 language</td>
#             </tr>
#             <tr>
#                         <th id="T_85fd9ed8_9236_11ea_a323_f018986d65f5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row3_col1" class="data row3 col1" >0.066140</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row3_col2" class="data row3 col2" >river miles country water small red side mouth hundred west creek land high called lake black missouri found great large </td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row3_col3" class="data row3 col3" >3 naturalfeatures</td>
#             </tr>
#             <tr>
#                         <th id="T_85fd9ed8_9236_11ea_a323_f018986d65f5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row4_col1" class="data row4 col1" >0.043180</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row4_col2" class="data row4 col2" >indians indian department rations agent cents florida pounds governor hundred war john secretary march lbs services june letter yards account </td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row4_col3" class="data row4 col3" >4 governmentregulations</td>
#             </tr>
#             <tr>
#                         <th id="T_85fd9ed8_9236_11ea_a323_f018986d65f5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row5_col1" class="data row5 col1" >0.085330</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row5_col2" class="data row5 col2" >general states united nations fort troops president ohio sir letter major war secretary hundred captain militia pay governor frontiers peace </td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row5_col3" class="data row5 col3" >5 military</td>
#             </tr>
#             <tr>
#                         <th id="T_85fd9ed8_9236_11ea_a323_f018986d65f5level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row6_col1" class="data row6 col1" >0.057850</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row6_col2" class="data row6 col2" >amount indian trade goods factory march agent agents year received office april georgetown furs traders superintendent statement account merchandise peltries </td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row6_col3" class="data row6 col3" >6 trade</td>
#             </tr>
#             <tr>
#                         <th id="T_85fd9ed8_9236_11ea_a323_f018986d65f5level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row7_col1" class="data row7 col1" >0.155600</td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row7_col2" class="data row7 col2" >treaty states united nation lands land commissioners line river president state part thousand hundred dollars made creek chiefs boundary tract </td>
#                         <td id="T_85fd9ed8_9236_11ea_a323_f018986d65f5row7_col3" class="data row7 col3" >7 treaties</td>
#             </tr>
#             <tr>
#                         <th id="T_85fd9ed8_9236_11ea_a323_f018986d65

# %%
# Represent the weights of the topics as a simple bar chart, using the author-created topic labels. 

topic_bar = nv15_topics.plot.bar(x='labels', y='topic_weight', rot=0, figsize=(30,10))

# %%
# The mallet .txt doc-topics output file was converted to a csv, the document number and filepath columns 
# were deleted (in a copy of the original file), the number format was changed from scientific to decimal with 
# 6 places, and the labels from the previous step were added as column headers
# in advance of reading the csv into a pandas dataframe.

nv15_docs1 = pd.read_csv("/Users/ritc/Desktop/DRC/NV/malletfiles/15/csv/nv15-docs1.csv", sep=',')

# Preview the data
nv15_docs1.head()
# Out:
#    '0 militaryohio'  '1 treatiesgeorgia'  '2 language'  '3 naturalfeatures'  \
# 0          0.000260             0.000205      0.008775             0.004540
# 1          0.029720             0.000014      0.000018             0.219811
# 2          0.000020             0.000016      0.000020             0.026364
# 3          0.000103             0.000082      0.000103             0.000112
# 4          0.000001             0.007374      0.000221             0.001212
#
#    '4 governmentregulations'  '5 military'  '6 trade'  '7 treaties'  \
# 0                   0.000184      0.059981   0.000246      0.835314
# 1                   0.000013      0.003590   0.000017      0.002422
# 2                   0.011397      0.000028   0.017256      0.337630
# 3                   0.000073      0.000145   0.000098      0.000264
# 4                   0.003907      0.037195   0.002147      0.011117
#
#    '8 religion'  '9 military2'  '10 governmentregulations2'  '11 treaties2'  \
# 0      0.000534       0.000619                     0.000805    2.060000e-04
# 1      0.024096       0.046081                     0.000056    7.736736e-03
# 2      0.003943       0.000047                     0.079090    3.410000e-04
# 3      0.000213       0.134184                     0.013884    8.180000e-05
# 4      0.001616       0.021919                     0.016271    8.850000e-07
#
#    '12 native-usrelations'  '13 georgia'  '14 treatycouncils'
# 0                 0.023610      0.000236             0.064484
# 1                 0.450734      0.000313             0.215379
# 2                 0.218401      0.138562             0.166885
# 3                 0.163682      0.000094             0.686882
# 4                 0.372054      0.514491             0.010475

# %%
# Represent the topic weights in each document as a heatmap.

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# Set standard figure size to 10 x 10 inches.
plt.rcParams['figure.figsize'] = (10.0, 10.0)

# Set type to float to avoid unexexpected type error.
nv15_docs1 = nv15_docs1[nv15_docs1.columns].astype(float)  # or int

# Simpler code to create the default heatmap with the given figure size in line one above. Make it accessible
# by using the 'inferno' colormap. 

sns.heatmap(nv15_docs1, cmap='inferno')

# %%
# Create a hierarchical heatmap using seaborn's "clustermap" method with default settings.
# By default this method will cluster by both rows and columns, which is what is most useful for this data.

sns.clustermap(nv15_docs1, cmap='inferno')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py:624: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# ## Exploring the model in _pandas_

# %%
# In the duplicate csv file of the document-topic output, delete the first column (document number),
# and remove the first part of the filepath so you're left with the filename, and then remove the file
# extension (.txt).
# First we need to read in the csv file that still has the filenames:

nv15_docs = pd.read_csv("/Users/ritc/Desktop/DRC/NV/malletfiles/15/csv/nv15-docs2.csv", sep=",")

nv15_docs.head()
# Out:
#          'filename'  '0 militaryohio'  '1 treatiesgeorgia'  '2 language'  \
# 0  ASP-IA-v1-82.txt          0.000260             0.000205      0.008775
# 1  ASP-IA-v1-82.txt          0.029720             0.000014      0.000018
# 2  ASP-IA-v1-82.txt          0.000020             0.000016      0.000020
# 3  ASP-IA-v1-82.txt          0.000103             0.000082      0.000103
# 4  ASP-IA-v1-82.txt          0.000001             0.007374      0.000221
#
#    '3 naturalfeatures'  '4 governmentregulations'  '5 military'  '6 trade'  \
# 0             0.004540                   0.000184      0.059981   0.000246
# 1             0.219811                   0.000013      0.003590   0.000017
# 2             0.026364                   0.011397      0.000028   0.017256
# 3             0.000112                   0.000073      0.000145   0.000098
# 4             0.001212                   0.003907      0.037195   0.002147
#
#    '7 treaties'  '8 religion'  '9 military2'  '10 governmentregulations2'  \
# 0      0.835314      0.000534       0.000619                     0.000805
# 1      0.002422      0.024096       0.046081                     0.000056
# 2      0.337630      0.003943       0.000047                     0.079090
# 3      0.000264      0.000213       0.134184                     0.013884
# 4      0.011117      0.001616       0.021919                     0.016271
#
#    '11 treaties2'  '12 native-usrelations'  '13 georgia'  '14 treatycouncils'
# 0    2.060000e-04                 0.023610      0.000236             0.064484
# 1    7.736736e-03                 0.450734      0.000313             0.215379
# 2    3.410000e-04                 0.218401      0.138562             0.166885
# 3    8.180000e-05                 0.163682      0.000094             0.686882
# 4    8.850000e-07                 0.372054      0.514491             0.010475

# %%
# Use the sort_values() method to sort the dataframe by a topic of interest. 

nv15_docs_religion = nv15_docs.sort_values("'8 religion'", ascending=False)

nv15_docs_religion.head(10)
# Out:
#            'filename'  '0 militaryohio'  '1 treatiesgeorgia'  '2 language'  \
# 177  ASP-IA-v1-82.txt          0.000283             0.000224      0.000281
# 468  ASP-IA-v1-82.txt          0.000165             0.000130      0.002868
# 150  ASP-IA-v1-82.txt          0.000206             0.000163      0.000205
# 50   ASP-IA-v1-82.txt          0.000177             0.000140      0.000177
# 291  ASP-IA-v1-82.txt          0.000211             0.000167      0.000210
# 155  ASP-IA-v1-82.txt          0.000198             0.000156      0.000197
# 305  ASP-IA-v1-82.txt          0.000133             0.000105      0.000132
# 343  ASP-IA-v1-82.txt          0.004980             0.000117      0.000147
# 29   ASP-IA-v1-82.txt          0.000206             0.000163      0.000205
# 571  ASP-IA-v1-82.txt          0.000145             0.000114      0.030962
#
#      '3 naturalfeatures'  '4 governmentregulations'  '5 military'  '6 trade'  \
# 177             0.000306                   0.000200      0.000395   0.000268
# 468             0.000179                   0.000117      0.000231   0.000156
# 150             0.000223                   0.000145      0.007025   0.000195
# 50              0.000192                   0.000126      0.000248   0.000168
# 291             0.000229                   0.000150      0.000295   0.000200
# 155             0.000214                   0.000140      0.000276   0.000187
# 305             0.000144                   0.000094      0.000186   0.008844
# 343             0.024324                   0.000104      0.000206   0.000140
# 29              0.000223                   0.000145      0.000287   0.000195
# 571             0.000157                   0.000102      0.000202   0.000137
#
#      '7 treaties'  '8 religion'  '9 military2'  '10 governmentregulations2'  \
# 177      0.000721      0.987476       0.000673                     0.000876
# 468      0.000421      0.973763       0.000393                     0.000511
# 150      0.003893      0.957204       0.000490                     0.000637
# 50       0.000453      0.954329       0.000423                     0.000550
# 291      0.000539      0.952556       0.003965                     0.004117
# 155      0.000504      0.952391       0.000470                     0.000612
# 305      0.000339      0.950519       0.000317                     0.009130
# 343      0.002792      0.947555       0.000351                     0.000457
# 29       0.010631      0.947097       0.000490                     0.000637
# 571      0.000369      0.946179       0.000344                     0.000448
#
#      '11 treaties2'  '12 native-usrelations'  '13 georgia'  \
# 177        0.000224                 0.007155      0.000257
# 468        0.005538                 0.014992      0.000150
# 150        0.000163                 0.028785      0.000187
# 50         0.000140                 0.042301      0.000161
# 291        0.000167                 0.029583      0.000192
# 155        0.000156                 0.043857      0.000179
# 305        0.000105                 0.029519      0.000121
# 343        0.000117                 0.018231      0.000134
# 29         0.000163                 0.032154      0.000187
# 571        0.000114                 0.015514      0.004873
#
#      '14 treatycouncils'
# 177             0.000661
# 468             0.000386
# 150             0.000481
# 50              0.000415
# 291             0.007419
# 155             0.000462
# 305             0.000311
# 343             0.000345
# 29              0.007219
# 571             0.000338

# %% [markdown]
# I'm currently working on a way to create the corpus as JSON file, which *should* remove the problem of character limits. Then, we can read the JSON file into a pandas dataframe and merge that dataframe with the <b>docs</b> dataframe in order to view the content of each document within the dataframe, rather than having to toggle between a jupyter notebook, finder window, and the plain text files, but for now, the latter option is a workaround.
#
# For our current exploration of the "military" topic, see the <a href="https://voyant-tools.org/?corpus=bdabc2797ab5226bfb1af925351d2ea5&panels=cirrus,reader,trends,summary,contexts">Voyant-Tools interface</a> that I have already pre-populated with the ten most closely related documents.
